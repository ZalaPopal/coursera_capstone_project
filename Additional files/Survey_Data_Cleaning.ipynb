# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("survey_data_cleaned.csv")
df.head()
# Out:
#    ResponseId                      MainBranch  Age           Employment  \
# 0           1  I am a developer by profession  17   Employed, full-time
# 1           2  I am a developer by profession  39   Employed, full-time
# 2           3  I am a developer by profession  49   Employed, full-time
# 3           4           I am learning to code  21    Student, full-time
# 4           5  I am a developer by profession  21    Student, full-time
#
#   RemoteWork   Check                                   CodingActivities  \
# 0     Remote  Apples                                              Hobby
# 1     Remote  Apples  Hobby;Contribute to open-source projects;Other...
# 2     Remote  Apples  Hobby;Contribute to open-source projects;Other...
# 3        NaN  Apples                                                NaN
# 4        NaN  Apples                                                NaN
#
#             EdLevel                                          LearnCode  \
# ...

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(15), int64(1), object(98)
# memory usage: 56.9+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cleaned = df[['ResponseId', 'Age', 'Employment', 'RemoteWork', 'EdLevel', 
          'YearsCode', 'YearsCodePro', 'Country', 'LanguageHaveWorkedWith',
          'DatabaseHaveWorkedWith', 'PlatformHaveWorkedWith',
          'WebframeHaveWorkedWith', 'LanguageWantToWorkWith',
          'DatabaseWantToWorkWith', 'PlatformWantToWorkWith',
          'WebframeWantToWorkWith', 'CompTotal', 'ConvertedCompYearly', 
          'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8',
           'JobSatPoints_9', 'JobSatPoints_10', 'JobSatPoints_11', 'JobSat']].copy()
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ResponseId              65437 non-null  int64
#  1   Age                     65115 non-null  object
#  2   Employment              65437 non-null  object
#  3   RemoteWork              54806 non-null  object
#  4   EdLevel                 60784 non-null  object
#  5   YearsCode               59869 non-null  float64
#  6   YearsCodePro            51610 non-null  float64
#  7   Country                 58930 non-null  object
#  8   LanguageHaveWorkedWith  59745 non-null  object
#  9   DatabaseHaveWorkedWith  50254 non-null  object
#  10  PlatformHaveWorkedWith  42366 non-null  object
#  11  WebframeHaveWorkedWith  45161 non-null  object
#  12  LanguageWantToWorkWith  55752 non-null  object
#  13  DatabaseWantToWorkWith  42558 non-null  object
# ...

# %%
df_cleaned.head()
# Out:
#    ResponseId  Age           Employment RemoteWork           EdLevel  \
# 0           1  17   Employed, full-time     Remote    Primary school
# 1           2  39   Employed, full-time     Remote         Bachelors
# 2           3  49   Employed, full-time     Remote           Masters
# 3           4  21    Student, full-time        NaN           College
# 4           5  21    Student, full-time        NaN  Secondary school
#
#    YearsCode  YearsCodePro         Country  \
# 0        NaN           NaN   United States
# 1       20.0          17.0  United Kingdom
# 2       37.0          27.0  United Kingdom
# 3        4.0           NaN          Canada
# 4        9.0           NaN          Norway
#
#                               LanguageHaveWorkedWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# ...

# %%
df_cleaned['Age'].unique()
# Out:
# array(['17 ', '39 ', '49 ', '21 ', '29 ', '59 ', nan, '65 years or older'],
#       dtype=object)

# %%
# Map Age categories to numeric values
age_map = {
    'Under 18 years old': 17,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70
}

df_cleaned['Age_num'] = df_cleaned['Age'].map(age_map)

# %%
df_cleaned['RemoteWork'].unique()
# Out:
# array(['Remote', nan, 'In-person', 'Hybrid'], dtype=object)

# %%
work_mapping = {'Hybrid (some remote, some in-person)': 'Hybrid'}

df_cleaned['RemoteWork'] = df_cleaned['RemoteWork'].replace(work_mapping)
display(df_cleaned['RemoteWork'].unique())
# Out:
# array(['Remote', nan, 'In-person', 'Hybrid'], dtype=object)

# %%
df_cleaned['EdLevel'].unique()
# Out:
# array(['Primary school', 'Bachelors', 'Masters', 'College',
#        'Secondary school', 'Professional degree', 'Associate degree',
#        'Something else', nan], dtype=object)

# %%
# Map messy education levels to simplified categories
edlevel_mapping = {
    "Bachelor’s degree (B.A., B.S., B.Eng., etc.)": "Bachelor",
    "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)": "Master",
    "Professional degree (JD, MD, Ph.D, Ed.D, etc.)": "Doctorate",
    "Associate degree (A.A., A.S., etc.)": "Associate",
    "Some college/university study without earning a degree": "Some College",
    "Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)": "Secondary School",
    "Primary/elementary school": "Primary School",
    "Something else": "Other"
}

df_cleaned['EdLevel'] = df_cleaned['EdLevel'].map(edlevel_mapping)
display(df_cleaned['EdLevel'].unique())
# Out:
# array([nan, 'Other'], dtype=object)

# %%
df_cleaned['Country'].unique()
# Out:
# array(['United States', 'United Kingdom', 'Canada', 'Norway',
#        'Uzbekistan', 'Serbia', 'Poland', 'Philippines', 'Bulgaria',
#        'Switzerland', 'India', 'Germany', 'Ireland', 'Italy', 'Ukraine',
#        'Australia', 'Brazil', 'Japan', 'Austria', 'Iran', 'France',
#        'Saudi Arabia', 'Romania', 'Turkey', 'Nepal', 'Algeria', 'Sweden',
#        'Netherlands', 'Croatia', 'Pakistan', 'Czech Republic',
#        'North Macedonia', 'Finland', 'Slovakia', 'Russia', 'Greece',
#        'Israel', 'Belgium', 'Mexico', 'Tanzania', 'Hungary', 'Argentina',
#        'Portugal', 'Sri Lanka', 'Latvia', 'China', 'Singapore', 'Lebanon',
#        'Spain', 'South Africa', 'Lithuania', 'Viet Nam',
#        'Dominican Republic', 'Indonesia', 'Kosovo', 'Morocco', 'Taiwan',
#        'Georgia', 'San Marino', 'Tunisia', 'Bangladesh', 'Nigeria',
#        'Liechtenstein', 'Denmark', 'Ecuador', 'Malaysia', 'Albania',
#        'Azerbaijan', 'Chile', 'Ghana', 'Peru', 'Bolivia', 'Egypt',
# ...

# %%
# Standardized Country name
country_mapping = {
    'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
    'United States of America': 'United States',
    'Republic of North Macedonia': 'North Macedonia',
    'Russian Federation': 'Russia',
    'United Republic of Tanzania': 'Tanzania',
    'Iran, Islamic Republic of...': 'Iran',
    'Venezuela, Bolivarian Republic of...': 'Venezuela',
    'Hong Kong (S.A.R.)': 'Hong Kong',
    'Democratic Republic of the Congo': 'DR Congo',
    'Congo, Republic of the...': 'Congo (Republic)',
    'Viet Nam': 'Vietnam',
    'Republic of Korea': 'South Korea',
    "Lao People's Democratic Republic": 'Laos',
    'Syrian Arab Republic': 'Syria',
    "Democratic People's Republic of Korea": 'North Korea',
    'Micronesia, Federated States of...': 'Micronesia',
    'Libyan Arab Jamahiriya': 'Libya',
    'Republic of Moldova': 'Moldova'
}

df_cleaned['Country'] = df_cleaned['Country'].replace(country_mapping)
display(df_cleaned['Country'].unique())
# Out:
# array(['United States', 'United Kingdom', 'Canada', 'Norway',
#        'Uzbekistan', 'Serbia', 'Poland', 'Philippines', 'Bulgaria',
#        'Switzerland', 'India', 'Germany', 'Ireland', 'Italy', 'Ukraine',
#        'Australia', 'Brazil', 'Japan', 'Austria', 'Iran', 'France',
#        'Saudi Arabia', 'Romania', 'Turkey', 'Nepal', 'Algeria', 'Sweden',
#        'Netherlands', 'Croatia', 'Pakistan', 'Czech Republic',
#        'North Macedonia', 'Finland', 'Slovakia', 'Russia', 'Greece',
#        'Israel', 'Belgium', 'Mexico', 'Tanzania', 'Hungary', 'Argentina',
#        'Portugal', 'Sri Lanka', 'Latvia', 'China', 'Singapore', 'Lebanon',
#        'Spain', 'South Africa', 'Lithuania', 'Vietnam',
#        'Dominican Republic', 'Indonesia', 'Kosovo', 'Morocco', 'Taiwan',
#        'Georgia', 'San Marino', 'Tunisia', 'Bangladesh', 'Nigeria',
#        'Liechtenstein', 'Denmark', 'Ecuador', 'Malaysia', 'Albania',
#        'Azerbaijan', 'Chile', 'Ghana', 'Peru', 'Bolivia', 'Egypt',
# ...

# %%
df_cleaned['YearsCodePro'].unique()
# Out:
# array([nan, 17., 27.,  7., 11., 25., 12., 10.,  3.,  0., 18., 37., 15.,
#        20.,  6.,  2., 16.,  8., 14.,  4., 45.,  1., 24., 29.,  5., 30.,
#        26.,  9., 33., 13., 35., 23., 22., 31., 19., 21., 28., 34., 32.,
#        40., 50., 39., 44., 42., 41., 36., 38., 51., 43., 47., 48., 46.,
#        49.])

# %%
yearcode_mapping = {'Less than 1 year': 0,
                'More than 50 years': 51}

df_cleaned['YearsCodePro'] = df_cleaned['YearsCodePro'].replace(yearcode_mapping)
display(df_cleaned['YearsCodePro'].unique())
# Out:
# array([nan, 17., 27.,  7., 11., 25., 12., 10.,  3.,  0., 18., 37., 15.,
#        20.,  6.,  2., 16.,  8., 14.,  4., 45.,  1., 24., 29.,  5., 30.,
#        26.,  9., 33., 13., 35., 23., 22., 31., 19., 21., 28., 34., 32.,
#        40., 50., 39., 44., 42., 41., 36., 38., 51., 43., 47., 48., 46.,
#        49.])

# %%
df_cleaned['YearsCode'] = df_cleaned['YearsCode'].replace(yearcode_mapping)
display(df_cleaned['YearsCode'].unique())
# Out:
# array([nan, 20., 37.,  4.,  9., 10.,  7.,  1., 15., 30., 31.,  6., 12.,
#        22.,  5., 36., 25., 44., 24., 18.,  3.,  8., 51., 11., 29., 40.,
#        39.,  2., 42., 34., 19., 35., 16., 33., 13., 23., 14., 28., 17.,
#        21., 43., 46., 26., 32., 41., 45., 27., 38., 50., 48., 47.,  0.,
#        49.])

# %%
df_cleaned['YearsCodePro'] = pd.to_numeric(df_cleaned['YearsCodePro'], errors='coerce')
df_cleaned['YearsCode'] = pd.to_numeric(df_cleaned['YearsCode'], errors='coerce')
df_cleaned['CompTotal'] = pd.to_numeric(df_cleaned['CompTotal'], errors='coerce')
df_cleaned['ConvertedCompYearly'] = pd.to_numeric(df_cleaned['ConvertedCompYearly'], errors='coerce')
df_cleaned['JobSatPoints_6'] = pd.to_numeric(df_cleaned['JobSatPoints_6'], errors='coerce')
df_cleaned['JobSatPoints_7'] = pd.to_numeric(df_cleaned['JobSatPoints_7'], errors='coerce')
df_cleaned['JobSatPoints_8'] = pd.to_numeric(df_cleaned['JobSatPoints_8'], errors='coerce')
df_cleaned['JobSatPoints_9'] = pd.to_numeric(df_cleaned['JobSatPoints_9'], errors='coerce')
df_cleaned['JobSatPoints_10'] = pd.to_numeric(df_cleaned['JobSatPoints_10'], errors='coerce')
df_cleaned['JobSatPoints_11'] = pd.to_numeric(df_cleaned['JobSatPoints_11'], errors='coerce')
df_cleaned['JobSat'] = pd.to_numeric(df_cleaned['JobSat'], errors='coerce')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ResponseId              65437 non-null  int64
#  1   Age                     65115 non-null  object
#  2   Employment              65437 non-null  object
#  3   RemoteWork              54806 non-null  object
#  4   EdLevel                 932 non-null    object
#  5   YearsCode               59869 non-null  float64
#  6   YearsCodePro            51610 non-null  float64
#  7   Country                 58930 non-null  object
#  8   LanguageHaveWorkedWith  59745 non-null  object
#  9   DatabaseHaveWorkedWith  50254 non-null  object
#  10  PlatformHaveWorkedWith  42366 non-null  object
#  11  WebframeHaveWorkedWith  45161 non-null  object
#  12  LanguageWantToWorkWith  55752 non-null  object
#  13  DatabaseWantToWorkWith  42558 non-null  object
# ...

# %%
#df_cleaned.to_csv('survey_data_cleaned.csv', index=False)

# %%
# Define multi-item columns
multi_item_columns = [
    'LanguageHaveWorkedWith',
    'DatabaseHaveWorkedWith',
    'PlatformHaveWorkedWith',
    'WebframeHaveWorkedWith',
    'LanguageWantToWorkWith',
    'DatabaseWantToWorkWith',
    'PlatformWantToWorkWith',
    'WebframeWantToWorkWith'
]

# %%
# Create reusable normalize function
def normalize_multivalue_column(df, column_name, id_col='ResponseId'):
    """
    Splits a semicolon-separated column into one row per value.
    """
    temp = df[[id_col, column_name]].dropna().copy()
    temp[column_name] = temp[column_name].str.split(';')
    temp = temp.explode(column_name)
    temp[column_name] = temp[column_name].str.strip()
    temp = temp[temp[column_name] != '']  # remove empty values
    return temp

# %%
# Normalize all multi-item columns
normalized_tables = {}

for col in multi_item_columns:
    normalized_tables[col] = normalize_multivalue_column(df_cleaned, col)

# %%
# Export all columns to csv file
for col, df_norm in normalized_tables.items():
    output_name = f"survey_{col.lower()}_normalized.csv"
    df_norm.to_csv(output_name, index=False)
    print(f"Saved: {output_name}")
# Out:
# Saved: survey_languagehaveworkedwith_normalized.csv
# Saved: survey_databasehaveworkedwith_normalized.csv
# Saved: survey_platformhaveworkedwith_normalized.csv
# Saved: survey_webframehaveworkedwith_normalized.csv
# Saved: survey_languagewanttoworkwith_normalized.csv
# Saved: survey_databasewanttoworkwith_normalized.csv
# Saved: survey_platformwanttoworkwith_normalized.csv
# Saved: survey_webframewanttoworkwith_normalized.csv

# %%
# Export all demographic columns to csv file
demographic_columns = ['ResponseId', 'Age', 'EdLevel', 'Country']
df_demographics = df_cleaned[demographic_columns].copy()
df_demographics.to_csv('survey_demographics.csv', index=False)

# %%
df_cleaned.isnull().sum()
# Out:
# ResponseId                    0
# Age                           0
# Employment                    0
# RemoteWork                10631
# EdLevel                   64505
# YearsCode                  5568
# YearsCodePro              13827
# Country                    6507
# LanguageHaveWorkedWith     5692
# DatabaseHaveWorkedWith    15183
# PlatformHaveWorkedWith    23071
# WebframeHaveWorkedWith    20276
# LanguageWantToWorkWith     9685
# DatabaseWantToWorkWith    22879
# PlatformWantToWorkWith    30905
# WebframeWantToWorkWith    26902
# CompTotal                 31697
# ConvertedCompYearly       42002
# JobSatPoints_6            35987
# JobSatPoints_7            35989
# JobSatPoints_8            35981
# JobSatPoints_9            35981
# JobSatPoints_10           35987
# JobSatPoints_11           35992
# JobSat                    36311
# Age_num                   64665
# dtype: int64

# %%
#filled the column "Age" using mean

Age1 = df_cleaned["Age"].mean

df_cleaned["Age"] =df_cleaned["Age"].fillna(Age1)

# %%
#filled the column "RemoteWork" using mode

RemoteWork1 = df_cleaned["RemoteWork"].mode()[0]

df_cleaned["RemoteWork"] = df_cleaned["RemoteWork"].fillna(RemoteWork1)

# %%
#filled the column "EdLevel" using mode

EdLevel1 = df_cleaned["EdLevel"].mode()[0]

df_cleaned["EdLevel"] = df_cleaned["EdLevel"].fillna(EdLevel1)

# %%
#filled the column "YearsCode" using median

YearsCode1 = df_cleaned["YearsCode"].median

df_cleaned["YearsCode"] = df_cleaned["YearsCode"].fillna(YearsCode1)

# %%
#filled the column "YearsCodePro" using median

YearsCodePro1 = df_cleaned["YearsCodePro"].median

df_cleaned["YearsCodePro"] = df_cleaned["YearsCodePro"].fillna(YearsCodePro1)

# %%
#filled the column "Country" using mode

Country1 = df["Country"].mode()[0]

df_cleaned["Country"] = df_cleaned["Country"].fillna(Country1)

# %%
#filled the column "CompTotal" using forward fill and the remaing missing values using median

df_cleaned["CompTotal"] = df_cleaned["CompTotal"].ffill()

CopmTotal1 = df_cleaned["CompTotal"].median()

df_cleaned["CompTotal"] = df_cleaned["CompTotal"].fillna(CompTotal1)

# %%
#filled the column "ConvertedCompYearly" using mean

CompYearly = df_cleaned["ConvertedCompYearly"].mean()

df_cleaned["ConvertedCompYearly"] = df_cleaned["ConvertedCompYearly"].fillna(CompYearly)

# %%
#filled the columns "JobSat" and "JobSatPoints" using Forward fill

df_cleaned["JobSatPoints_6"] = df_cleaned["JobSatPoints_6"].ffill()
df_cleaned["JobSatPoints_7"] = df_cleaned["JobSatPoints_7"].ffill()
df_cleaned["JobSatPoints_8"] = df_cleaned["JobSatPoints_8"].ffill()
df_cleaned["JobSatPoints_9"] = df_cleaned["JobSatPoints_9"].ffill()
df_cleaned["JobSatPoints_10"] = df_cleaned["JobSatPoints_10"].ffill()
df_cleaned["JobSatPoints_11"] = df_cleaned["JobSatPoints_11"].ffill()
df_cleaned["JobSat"] = df_cleaned["JobSat"].ffill()

# %%
#filled the column "LanguageHaveWorkedWith" and "LanguageWantToWorkWith" using mode

lang1 = df_cleaned["LanguageHaveWorkedWith"].mode()[0]

df_cleaned["LanguageHaveWorkedWith"] =df_cleaned["LanguageHaveWorkedWith"].fillna(lang1)

lang2 = df_cleaned["LanguageWantToWorkWith"].mode()[0]

df_cleaned["LanguageWantToWorkWith"] =df_cleaned["LanguageWantToWorkWith"].fillna(lang2)

# %%
#filled the column "DatabaseHaveWorkedWith" and "DatabaseWantToWorkWith" using mode

dat1 = df_cleaned["DatabaseHaveWorkedWith"].mode()[0]

df_cleaned["DatabaseHaveWorkedWith"] =df_cleaned["DatabaseHaveWorkedWith"].fillna(dat1)

dat2 = df_cleaned["DatabaseWantToWorkWith"].mode()[0]

df_cleaned["DatabaseWantToWorkWith"] =df_cleaned["DatabaseWantToWorkWith"].fillna(dat2)

# %%
#filled the column "PlatformHaveWorkedWith" and "PlatformWantToWorkWith" using mode

plat1 = df_cleaned["PlatformHaveWorkedWith"].mode()[0]

df_cleaned["PlatformHaveWorkedWith"] =df_cleaned["PlatformHaveWorkedWith"].fillna(plat1)

plat2 = df_cleaned["PlatformWantToWorkWith"].mode()[0]

df_cleaned["PlatformWantToWorkWith"] =df_cleaned["PlatformWantToWorkWith"].fillna(plat2)

# %%
#filled the column "WebframeHaveWorkedWith" and "WebframeWantToWorkWith" using mode

web1 = df_cleaned["WebframeHaveWorkedWith"].mode()[0]

df_cleaned["WebframeHaveWorkedWith"] =df_cleaned["WebframeHaveWorkedWith"].fillna(web1)

web2 = df_cleaned["WebframeWantToWorkWith"].mode()[0]

df_cleaned["WebframeWantToWorkWith"] =df_cleaned["WebframeWantToWorkWith"].fillna(web2)

# %%
df_cleaned.isnull().sum()
# Out:
# ResponseId                    0
# Age                           0
# Employment                    0
# RemoteWork                    0
# EdLevel                       0
# YearsCode                     0
# YearsCodePro                  0
# Country                       0
# LanguageHaveWorkedWith        0
# DatabaseHaveWorkedWith        0
# PlatformHaveWorkedWith        0
# WebframeHaveWorkedWith        0
# LanguageWantToWorkWith        0
# DatabaseWantToWorkWith        0
# PlatformWantToWorkWith        0
# WebframeWantToWorkWith        0
# CompTotal                     0
# ConvertedCompYearly           0
# JobSatPoints_6                1
# JobSatPoints_7                1
# JobSatPoints_8                1
# JobSatPoints_9                1
# JobSatPoints_10               1
# JobSatPoints_11               1
# JobSat                       10
# Age_num                   64665
# dtype: int64

# %%
df["ConvertedCompYearly_Log"] = np.log1p(df["ConvertedCompYearly"])

# %%
df["ConvertedCompYearly_MinMax"] = df["ConvertedCompYearly"].value_counts(normalize = True)
